# %%
import  requests
import json
import pandas as pd
from bs4 import BeautifulSoup

url='https://www.104.com.tw/jobs/search/?ro=0&jobcat=2007000000&kwop=7&keyword=PYTHON&area=6001001000%2C6001002014%2C6001002015%2C6001002011&order=15&asc=0&page=1&mode=s&jobsource=2018indexpoc'
res=requests.get(url)
html=res.text
soup = BeautifulSoup(html, 'html.parser')
titleJobList = soup.select('article')
Joburl=titleJobList[0].find_all("a")[0].get("href")
#print(titleJobList[0].find_all("a")[0].get("href"))
insideurl="https:"+Joburl
#print(insideurl)
resin=requests.get(insideurl)
inhtml=resin.text
soupinhtml=BeautifulSoup(inhtml,'html.parser')
print(soupinhtml)
print(soupinhtml.find("title").text.split('｜',2))
work=soupinhtml.select("meta")[4]
#print(work)
# Out:
# <!DOCTYPE html>
#
# <html lang="zh-Hant-TW">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width,initial-scale=1.0" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <title>2021 Turing Plan -儲備AI科學家- 百萬年薪 火熱開放申請中!｜永豐商業銀行股份有限公司｜台北市中山區－104 人力銀行</title>
# <meta content="【工作內容】台北市中山區 - 【你的薪資你決定，百萬Turing 就是你】
#
# Alan Mathison Turing
# 被稱為AI之父，本專案特命Turing Plan，以尋找為最頂尖的程式技術菁英加入。
# 計畫共計二年，不預設組別…。薪資：待遇面議（經常性薪資達4萬元或以上）。職務類別：軟體設計工程師、演算法開發工程師、儲備幹部。休假制度：週休二日。可上班日：不限。工作性質：全職。主動應徵、找工作，請上 104 人力銀行投遞履歷。" name="description"/>
# <link href="https://www.104.com.tw/job/6x0q4" rel="canonical"/>
# <link href="https://m.104.com.tw/job/6x0q4" media="handheld" rel="alternate"/>
# <link href="https://m.104.com.tw/job/6x0q4" media="only screen and (max-width: 640px)" rel="alternate"/>
# <link href="https://m.104.com.tw/amp/job/6x0q4" rel="amphtml"/>
# ...

# %%
print(titleJobList[0].get("data-cust-name"))
print(titleJobList[0].get("data-job-name"))
print(titleJobList[0].p.text)
# Out:
# 科熱臺灣有限公司
# 全端軟體開發工程師
# 負責大型專案的系統開發、測試和維護支援。
# 內容包含：
# 1. 系統分析、設計和開發
# 2. 擬定測試計畫、測試案例/腳本、建置測試環境、準備測試資料和執行測試
# 3. UAT和系統上線支援
#
# 必要條件
# – 熟悉前端 HTML/CSS/JavaScript 等技術。
# – 熟悉後端 Java 或 C# 程式開發。
# – 熟悉關聯式資料庫設計。
# – 了解 Git 開發流程。
# – 邏輯分析能力強，可獨立運作，擁有優異解決問題的能力。
# – 能有效應付緊湊的專案進度。

# %%
data=[]
for name in titleJobList:
    if name.get("data-cust-name") is None :
        continue
    else:
        data.append([name.get("data-cust-name"),name.get("data-job-name"),name.p.text])
mydf= pd.DataFrame(data=data,columns=['Cust Name','Job Name',"Work"]) 
mydf
# Out:
#                             Cust Name  \
# 0                         希格斯資訊科技有限公司
# 1                        永豐商業銀行股份有限公司
# 2                            科熱臺灣有限公司
# 3                            創順科技有限公司
# 4                     美商格拉思緹有限公司台灣分公司
# 5                          華碩雲端股份有限公司
# 6                GoFreight_聖學科技股份有限公司
# 7                     美商格拉思緹有限公司台灣分公司
# 8                        瑪樂愛迪科技股份有限公司
# 9                       春水堂科技娛樂股份有限公司
# 10                         台灣現觀股份有限公司
# 11                           達暉資訊有限公司
# 12                         禾向數位科技有限公司
# 13                         技嘉科技股份有限公司
# 14                         億力資訊股份有限公司
# 15  緯德科技股份有限公司 (TechLink Corporation)
# 16                     臺灣發展軟體科技股份有限公司
# 17                         日新軟體股份有限公司
# 18                         瞬聯科技股份有限公司
# 19                      新據點廣告事業股份有限公司
# 20                           米約科技有限公司
# 21                         文境資科股份有限公司
# 22                         橋新科技股份有限公司
# ...
