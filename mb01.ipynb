# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import openpyxl
from openpyxl import Workbook

page=1
list = []
for j in range(1,2):
    url = 'https://www.mobile01.com/topiclist.php?f=202&p={}'
    headers = {
        'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 11_2_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36'
    }

    res = requests.get(url.format(page), headers=headers)
    html = res.text

    soup = BeautifulSoup(html, 'html.parser')

    titlelist = soup.find_all('a', class_="c-link u-ellipsis")
    
    for title in titlelist:
        urlshop = "https://www.mobile01.com/" + title.get('href')
        reshop = requests.get(urlshop, headers=headers)
        htmlshop = reshop.text
        soupshop = BeautifulSoup(htmlshop, 'html.parser')
        shoptitle=soupshop.find_all('div',class_="l-heading__title",limit=3)
        list.append(shoptitle[2].text)
        
        shoptext=soupshop.find('div',itemprop="articleBody")
        list.append(shoptext.text)
    page+=1
    
step = 2
slicelist = [list[i:i + step] for i in range(0, len(list), step)]
shop_df = pd.DataFrame(slicelist)
shop_df.index = shop_df.index + 1  # 自訂索引值
shop_df.columns = ["文章標題", "內文"]
print(shop_df)

shop_df.to_excel('travelinfo.xlsx')
# Out:
#                                                  文章標題  \
# 1                   \n最美燈會「2021月津港燈節」六月底回歸，將點亮台南夏夜！\n
# 2   \n【台南中西區｜住宿】煙波大飯店台南館。位於市中心，步行就到美術館，備有露天游泳池，早餐自...
# 3                                 \n美食不怕巷弄深&裏葉終於吃到了\n
# 4   \n[台南五星級飯店]台南大員皇冠假日酒店--早餐篇/取餐除了口罩還要戴手套，防疫一極棒/品...
# 5   \n【臺南美食】舒適小清新用餐空間｜單點170元起附飲料｜升級套餐80元｜當月壽星享折扣｜義...
# 6   \n台南烤雞腿便當／嚴選八兩重雞腿／限量供應晚來吃不到／現點現烤搭配獨家特調日式醬汁／當天採...
# 7   \n【台南甜點】營業時間還沒到就大排長龍的台南巷弄甜點店│貳林工作室 erlin studi...
# 8            \n臺南市 西港 金砂里花旗木步道 — 盛開中的花旗木步道，懷想昔日糖鐵點滴\n
# 9                      \n台南市育樂街-過往的回憶-請問有朋友是住在那附近嘛？\n
# 10  \n【台南楠西｜景點】楠西萬佛寺。最新消息5/19採預約制，免費景點，台版吳哥窟，猶如古墓奇...
# 11  \n【台南超萌甜點】台南手作甜點 造型超吸睛 IG打卡熱門店│尋路。甜│不提供訂位│文青日式...
# 12  \n【網美風住宿】台南民宿 Yes Yes I am willing 我願意 平價民宿│台南...
# 13  \n[台南五星級飯店]台南大員皇冠假日酒店--房間篇/房間竟然有中島！你說稀奇不稀奇？/隱藏...
# 14  \n台南比利時鬆餅／隱身傳統市場內／嚴選原物料注重品質／一週只賣3天／晚上才營業只開4小時／...
# 15  \n【台南美食】沖繩蝦蝦飯在台南 丸飯食事處│台南中西區｜台南火車站│麵茶銀絲卷好好吃捏！❤...
# 16  \n台南親子景點推薦│山上花園水道博物館。超詳細介紹！有互動遊戲、解謎遊戲、鹽冰淇淋、沙坑、...
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import openpyxl
from openpyxl import Workbook

urlshop = "https://www.mobile01.com/topicdetail.php?f=202&t=6351458" 
reshop = requests.get(urlshop, headers=headers)
htmlshop = reshop.text
soupshop = BeautifulSoup(htmlshop, 'html.parser')
shoptitle=soupshop.find_all('div',class_="l-heading__title",limit=3)
print(shoptitle[2].text)
shoptext=soupshop.find('div',itemprop="articleBody")
print(shoptext.text)
# Out:
# 【台南中西區｜住宿】煙波大飯店台南館。位於市中心，步行就到美術館，備有露天游泳池，早餐自助吧超推薦
#
#
#                                  位在市中心非常熱鬧的路段
# 步行就可以抵達美術館以及品嚐小吃
# 定位以商務型態為主的煙波台南館，房間乾淨舒適度及服務沒話說
# 還有健身房、三溫暖以及露天游泳池
# 早餐自助吧更是有牛肉湯、平崎生吐司，菜色多樣化，非常推薦
# 『煙波大飯店台南館』
# agoda最新房價查詢
#
# 這是我開設的Youtube頻道
# 再懇請大家按個訂閱開啟小鈴鐺喔
# https://www.youtube.com/jasonslife
#
# 煙波大飯店位於繁榮市區內，走出飯店對面就是美術館二館
# 附近還有福記肉圓，甚至古蹟環繞，後方就是新光三越和藍晒圖園區
# 入住這裡一點都不無聊，超方便的
# 【煙波大飯店台南館】
# agoda最新房價查詢
#
# 落落大方的大廳，挑高設計及高掛著藝術裝置
# 顯得煙波的大器之風，煙波台南館就座落在非常熱鬧的路段
#
# 因為入住當天為週末，所以房間的狀態是客滿的
# 為了有效管控分流早餐的人潮，可以建議選擇以下的時段入場喔
#
# 今天入住的房型為【尊榮套房】，坪數為12坪
# 聽服務人員介紹尊榮套房，是每層樓分布在左右兩側
# 也就是邊間的意思，如果各位會在意的話，就在考慮看看喔
#
# 尊榮套房的空間配置，就是有個客廳、辦公區、衛浴區及睡眠區
# 客廳空間算滿寬廣的，沙發足夠於2~3人坐
# 很適合買個宵夜或晚餐回來飯店，邊看電視邊聊天，很不錯的空間
#
# 一旁的L型木製辦公桌結合了Mini Bar和辦公區
# MiniBar內該有的配備都有，冰箱內的汽水和運動飲料也是免費的
# 除此之外，貼心準備了網路線和充電線，這個在一般飯店比較少看到
# 不曉得是不是只有尊榮套房有
#
# 辦公桌上有一個吸睛的皮革藍芽喇叭
#  夜深人靜可以放個慵懶的音樂，小酌一下非常蘇胡
#
# 睡眠區是標準的180*200公分雙人床
# 睡起來是挺不錯的，是說本人比較不會挑床鋪軟硬度，小酌以後都好睡XD
#
#  衛浴空間，單一設計的洗臉台，左右兩邊分別是淋浴空間及廁所空間
# 分隔設計，互不相干擾，重點是有浴缸就給讚
#
# ...
